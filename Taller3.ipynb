# %% [markdown]
# <a href="https://colab.research.google.com/github/victoriaPaez/MujeresDigitales2021/blob/main/Taller3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-effb8eac-c92e-416d-a4a1-c063a478ee90" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-effb8eac-c92e-416d-a4a1-c063a478ee90">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pokemon_data.csv to pokemon_data.csv

# %%
import io
df =pd.read_csv(io.BytesIO(uploaded['pokemon_data.csv']), sep=",")
df.head(10)
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 0  1                  Bulbasaur  Grass  ...    45           1      False
# 1  2                    Ivysaur  Grass  ...    60           1      False
# 2  3                   Venusaur  Grass  ...    80           1      False
# 3  3      VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4                 Charmander   Fire  ...    65           1      False
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
#
# [10 rows x 12 columns]

# %%
pk_type=df['Type 1'].unique
df['catched']=False
df.head(10)
# Out:
#    #                       Name Type 1  ... Generation Legendary catched
# 0  1                  Bulbasaur  Grass  ...          1     False   False
# 1  2                    Ivysaur  Grass  ...          1     False   False
# 2  3                   Venusaur  Grass  ...          1     False   False
# 3  3      VenusaurMega Venusaur  Grass  ...          1     False   False
# 4  4                 Charmander   Fire  ...          1     False   False
# 5  5                 Charmeleon   Fire  ...          1     False   False
# 6  6                  Charizard   Fire  ...          1     False   False
# 7  6  CharizardMega Charizard X   Fire  ...          1     False   False
# 8  6  CharizardMega Charizard Y   Fire  ...          1     False   False
# 9  7                   Squirtle  Water  ...          1     False   False
#
# [10 rows x 13 columns]

# %%
mask= df['Type 1']== 'Grass'
mask
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4          False
#            ...
# 796        False
# 797        False
# 798        False
# 799        False
# catched    False
# Name: Type 1, Length: 801, dtype: bool

# %%
df.loc[mask,'catched']=True
df.head(10)
# Out:
#    #                       Name Type 1  ... Generation Legendary catched
# 0  1                  Bulbasaur  Grass  ...          1     False    True
# 1  2                    Ivysaur  Grass  ...          1     False    True
# 2  3                   Venusaur  Grass  ...          1     False    True
# 3  3      VenusaurMega Venusaur  Grass  ...          1     False    True
# 4  4                 Charmander   Fire  ...          1     False   False
# 5  5                 Charmeleon   Fire  ...          1     False   False
# 6  6                  Charizard   Fire  ...          1     False   False
# 7  6  CharizardMega Charizard X   Fire  ...          1     False   False
# 8  6  CharizardMega Charizard Y   Fire  ...          1     False   False
# 9  7                   Squirtle  Water  ...          1     False   False
#
# [10 rows x 13 columns]

# %% [markdown]
# gggggg

# %%
import io
df1 =pd.read_csv(io.BytesIO(uploaded['pokemon_data.csv']), sep=",")
df1.head(10)
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 0  1                  Bulbasaur  Grass  ...    45           1      False
# 1  2                    Ivysaur  Grass  ...    60           1      False
# 2  3                   Venusaur  Grass  ...    80           1      False
# 3  3      VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4                 Charmander   Fire  ...    65           1      False
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
#
# [10 rows x 12 columns]

# %%
pk_type=df1['Type 1'].unique
df1['Interes']=False
df1.head(10)
# Out:
#    #                       Name Type 1  ... Generation  Legendary  Interes
# 0  1                  Bulbasaur  Grass  ...          1      False    False
# 1  2                    Ivysaur  Grass  ...          1      False    False
# 2  3                   Venusaur  Grass  ...          1      False    False
# 3  3      VenusaurMega Venusaur  Grass  ...          1      False    False
# 4  4                 Charmander   Fire  ...          1      False    False
# 5  5                 Charmeleon   Fire  ...          1      False    False
# 6  6                  Charizard   Fire  ...          1      False    False
# 7  6  CharizardMega Charizard X   Fire  ...          1      False    False
# 8  6  CharizardMega Charizard Y   Fire  ...          1      False    False
# 9  7                   Squirtle  Water  ...          1      False    False
#
# [10 rows x 13 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-362-f25288a4999b> in <module>()
# ----> 1 if df1[(df1['Type 1']=='Fire')& (df1['Legendary']==True)]:
#       2   print(df1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1328     def __nonzero__(self):
#    1329         raise ValueError(
# -> 1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1332         )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df1 = df1[(df1['Type 1']=='Fire')& (df1['Legendary']==True)]
df1.head(100)
# Out:
#        #       Name Type 1  Type 2  ...  Speed  Generation  Legendary  Interes
# 158  146    Moltres   Fire  Flying  ...     90           1       True    False
# 263  244      Entei   Fire     NaN  ...    100           2       True    False
# 270  250      Ho-oh   Fire  Flying  ...     90           2       True    False
# 542  485    Heatran   Fire   Steel  ...     77           4       True    False
# 799  721  Volcanion   Fire   Water  ...     70           6       True    False
#
# [5 rows x 13 columns]

# %%
mask= df1['Type 1']== 'Fire'
mask
# Out:
# 158    True
# 263    True
# 270    True
# 542    True
# 799    True
# Name: Type 1, dtype: bool

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.loc[mask,'Interes']=True
df1.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#        #       Name Type 1  Type 2  ...  Speed  Generation  Legendary  Interes
# 158  146    Moltres   Fire  Flying  ...     90           1       True     True
# 263  244      Entei   Fire     NaN  ...    100           2       True     True
# 270  250      Ho-oh   Fire  Flying  ...     90           2       True     True
# 542  485    Heatran   Fire   Steel  ...     77           4       True     True
# 799  721  Volcanion   Fire   Water  ...     70           6       True     True
#
# [5 rows x 13 columns]

# %%
df1.head()
# Out:
#        #       Name Type 1  Type 2  ...  Speed  Generation  Legendary  Interes
# 158  146    Moltres   Fire  Flying  ...     90           1       True     True
# 263  244      Entei   Fire     NaN  ...    100           2       True     True
# 270  250      Ho-oh   Fire  Flying  ...     90           2       True     True
# 542  485    Heatran   Fire   Steel  ...     77           4       True     True
# 799  721  Volcanion   Fire   Water  ...     70           6       True     True
#
# [5 rows x 13 columns]

# %%
df1.index
df1.loc[:, 'Type 1'] # Columna tip
df1.loc[:, ['Type 1', 'Legendary']] # Columnas tip, sex y day

df1[df1['Type 1']=='Fire']

is_male = df1.loc[:, 'Type 1'] == 'Fire'
df1_male = df1.loc[is_male]
df1_male.head(50)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-305-9136e6483b78> in <module>()
#       3 df1.loc[:, ['Type 1', 'Legendary']] # Columnas tip, sex y day
#       4
# ----> 5 df1[df1['Type 1']=='Fire',['Legendary']==True]
#       6
#       7 is_male = df1.loc[:, 'Type 1'] == 'Fire'
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             casted_key = self._maybe_cast_indexer(key)
#    2897             try:
# ...

# %%
a=df1[df1['Legendary']==True]
a
# Out:
#        #                 Name    Type 1  ... Generation  Legendary  Interes
# 156  144             Articuno       Ice  ...          1       True    False
# 157  145               Zapdos  Electric  ...          1       True    False
# 158  146              Moltres      Fire  ...          1       True    False
# 162  150               Mewtwo   Psychic  ...          1       True    False
# 163  150  MewtwoMega Mewtwo X   Psychic  ...          1       True    False
# ..   ...                  ...       ...  ...        ...        ...      ...
# 795  719              Diancie      Rock  ...          6       True    False
# 796  719  DiancieMega Diancie      Rock  ...          6       True    False
# 797  720  HoopaHoopa Confined   Psychic  ...          6       True    False
# 798  720   HoopaHoopa Unbound   Psychic  ...          6       True    False
# 799  721            Volcanion      Fire  ...          6       True    False
#
# [65 rows x 13 columns]

# %%
df1.index
df1.loc[:, 'Type 1'] # Columna tip
df1.loc[:, ['Type 1', 'Legendary']] # Columnas tip, sex y day

is_male = df1.loc[:, 'Legendary'] == True
df1_male = df1.loc[is_male]
df1_male.head(200)
# Out:
#        #                 Name    Type 1  ... Generation  Legendary  Interes
# 156  144             Articuno       Ice  ...          1       True    False
# 157  145               Zapdos  Electric  ...          1       True    False
# 158  146              Moltres      Fire  ...          1       True     True
# 162  150               Mewtwo   Psychic  ...          1       True    False
# 163  150  MewtwoMega Mewtwo X   Psychic  ...          1       True    False
# ..   ...                  ...       ...  ...        ...        ...      ...
# 795  719              Diancie      Rock  ...          6       True    False
# 796  719  DiancieMega Diancie      Rock  ...          6       True    False
# 797  720  HoopaHoopa Confined   Psychic  ...          6       True    False
# 798  720   HoopaHoopa Unbound   Psychic  ...          6       True    False
# 799  721            Volcanion      Fire  ...          6       True     True
#
# [65 rows x 13 columns]

# %%
mask= df1_male['Type 1']== 'Fire'
df1_male.loc[mask,'Interes']=True
df1_male.head(50)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)
#        #                      Name    Type 1  ... Generation  Legendary  Interes
# 156  144                  Articuno       Ice  ...          1       True    False
# 157  145                    Zapdos  Electric  ...          1       True    False
# 158  146                   Moltres      Fire  ...          1       True     True
# 162  150                    Mewtwo   Psychic  ...          1       True    False
# 163  150       MewtwoMega Mewtwo X   Psychic  ...          1       True    False
# 164  150       MewtwoMega Mewtwo Y   Psychic  ...          1       True    False
# ...

# %%
is_male = df1.loc[:, 'Legendary'] == False
df1_male = df1.loc[is_male]
df1_male.head(200)
# Out:
#        #                   Name  Type 1  ... Generation  Legendary  Interes
# 0      1              Bulbasaur   Grass  ...          1      False    False
# 1      2                Ivysaur   Grass  ...          1      False    False
# 2      3               Venusaur   Grass  ...          1      False    False
# 3      3  VenusaurMega Venusaur   Grass  ...          1      False    False
# 4      4             Charmander    Fire  ...          1      False     True
# ..   ...                    ...     ...  ...        ...        ...      ...
# 201  186               Politoed   Water  ...          2      False    False
# 202  187                 Hoppip   Grass  ...          2      False    False
# 203  188               Skiploom   Grass  ...          2      False    False
# 204  189               Jumpluff   Grass  ...          2      False    False
# 205  190                  Aipom  Normal  ...          2      False    False
#
# [200 rows x 13 columns]

# %%
b=df1[df1['Type 1']=='Fire']

# %%
pk_type=df1['Type 1'].unique
pk_type
data=df1['Type 1'].to_list()

result = []
for item in data:
    if item not in result:
        result.append(item)

result

for j in result:
        if(j=='Fire'):
          a=df[df['Type 1']==j]['Attack']
          print("el promedio de: ",j, "es ",a.mean())
          print(j)
          break
# Out:
# el promedio de:  Fire es  84.76923076923077
# Fire

# %%
mask1=df['Legendary']==True
mask1
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 796         True
# 797         True
# 798         True
# 799         True
# catched     True
# Name: Legendary, Length: 801, dtype: bool

# %% [markdown]
# dddddd

# %%
pk_type=df['Type 1'].unique
pk_type
type(df['Type 1'].to_list())
data=df['Type 1'].to_list()

result = []
for item in data:
    if item not in result:
        result.append(item)

result
# Out:
# ['Grass',
#  'Fire',
#  'Water',
#  'Bug',
#  'Normal',
#  'Poison',
#  'Electric',
#  'Ground',
#  'Fairy',
#  'Fighting',
#  'Psychic',
#  'Rock',
#  'Ghost',
#  'Ice',
#  'Dragon',
#  'Dark',
#  'Steel',
#  'Flying',
#  True]

# %%
for j in result:
        if(j=='Grass'):
          a=df[df['Type 1']==j]['Attack']
          print("el promedio de: ",j, "es ",a.mean())
          print(j)
          break
# Out:
# el promedio de:  Grass es  73.21428571428571
# Grass

# %%
if pk_type =='Grass':
  a=pk_type
  print(a)
else:
  pk_type

# %%
a=df[df['Type 1']=='Grass']['Attack']
print("el promedio es ",a.mean())
# Out:
# el promedio es  73.21428571428571
